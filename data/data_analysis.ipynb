# %%
import pandas as pd
data = pd.read_csv('/Users/bytedance/Desktop/project/reading/data/dataset/20240901/all-word-feature-20240901-27.csv')
data.head(1000)
# Out:
#      exp_id  page_id  fix_seq_id  row_idx  article_id user  sentence_id  \
# 0       902     1588           0        0          39  qxy            0
# 1       902     1588           0        0          39  qxy            0
# 2       902     1588           0        0          39  qxy            0
# 3       902     1588           0        0          39  qxy            0
# 4       902     1588           0        0          39  qxy            0
# ..      ...      ...         ...      ...         ...  ...          ...
# 995     902     1589          20       17          39  qxy            0
# 996     902     1589          20       17          39  qxy            0
# 997     902     1589          20       17          39  qxy            0
# 998     902     1589          20       17          39  qxy            0
# 999     902     1589          20       17          39  qxy            0
#
#           word  word_understand  sentence_understand  ...  \
# ...
